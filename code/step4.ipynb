# %%
import pandas as pd
import statsmodels.api as sm

# %%
T = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
for t in T:
    df = pd.read_csv('../data/step3/{}.csv'.format(t), index_col=0)
    FX = df[['rm-rf', 'SMB', 'HML', 'RMW']]
    FY = df[['CMA']]
    FX = sm.add_constant(FX)

    model = sm.OLS(FY, FX).fit()
    predictions = model.predict(FX)
    
    print(model.summary(), '\n\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     9.722
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           0.000155
# Time:                        18:44:59   Log-Likelihood:                 82.590
# No. Observations:                  25   AIC:                            -155.2
# Df Residuals:                      20   BIC:                            -149.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0063      0.014     -0.450      0.658      -0.036       0.023
# rm-rf         -0.0362      0.052     -0.694      0.496      -0.145       0.073
# SMB           -0.0109      0.019     -0.579      0.569      -0.050       0.028
# HML           -0.2221      0.066     -3.385      0.003      -0.359      -0.085
# RMW            0.7674      0.147      5.221      0.000       0.461       1.074
# ==============================================================================
# Omnibus:                        1.075   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.584   Jarque-Bera (JB):                0.869
# Skew:                          -0.162   Prob(JB):                        0.648
# Kurtosis:                       2.146   Cond. No.                         76.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     10.85
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           7.67e-05
# Time:                        18:44:59   Log-Likelihood:                 87.666
# No. Observations:                  25   AIC:                            -165.3
# Df Residuals:                      20   BIC:                            -159.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0105      0.022      0.477      0.638      -0.036       0.057
# rm-rf          0.0478      0.084      0.571      0.575      -0.127       0.223
# SMB           -0.0419      0.019     -2.180      0.041      -0.082      -0.002
# HML           -0.0668      0.082     -0.816      0.424      -0.238       0.104
# RMW            0.6305      0.103      6.104      0.000       0.415       0.846
# ==============================================================================
# Omnibus:                        0.499   Durbin-Watson:                   1.662
# Prob(Omnibus):                  0.779   Jarque-Bera (JB):                0.351
# Skew:                           0.270   Prob(JB):                        0.839
# Kurtosis:                       2.790   Cond. No.                         77.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     2.791
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):             0.0543
# Time:                        18:44:59   Log-Likelihood:                 69.759
# No. Observations:                  25   AIC:                            -129.5
# Df Residuals:                      20   BIC:                            -123.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0345      0.076     -0.455      0.654      -0.193       0.124
# rm-rf         -0.1267      0.301     -0.421      0.678      -0.755       0.501
# SMB            0.0084      0.064      0.131      0.897      -0.125       0.142
# HML           -0.1220      0.105     -1.158      0.261      -0.342       0.098
# RMW            0.5478      0.175      3.132      0.005       0.183       0.913
# ==============================================================================
# Omnibus:                        6.624   Durbin-Watson:                   1.672
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                4.665
# Skew:                           0.990   Prob(JB):                       0.0970
# Kurtosis:                       3.747   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.517
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     5.342
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):            0.00430
# Time:                        18:44:59   Log-Likelihood:                 72.802
# No. Observations:                  25   AIC:                            -135.6
# Df Residuals:                      20   BIC:                            -129.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0360      0.024      1.528      0.142      -0.013       0.085
# rm-rf          0.1497      0.100      1.498      0.150      -0.059       0.358
# SMB           -0.0770      0.024     -3.199      0.005      -0.127      -0.027
# HML           -0.1386      0.075     -1.850      0.079      -0.295       0.018
# RMW            0.5212      0.125      4.175      0.000       0.261       0.782
# ==============================================================================
# Omnibus:                        0.089   Durbin-Watson:                   2.379
# Prob(Omnibus):                  0.957   Jarque-Bera (JB):                0.210
# Skew:                           0.122   Prob(JB):                        0.900
# Kurtosis:                       2.623   Cond. No.                         47.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     18.11
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           1.98e-06
# Time:                        18:44:59   Log-Likelihood:                 69.902
# No. Observations:                  25   AIC:                            -129.8
# Df Residuals:                      20   BIC:                            -123.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0224      0.013      1.676      0.109      -0.005       0.050
# rm-rf          0.1475      0.070      2.107      0.048       0.001       0.294
# SMB           -0.0728      0.016     -4.494      0.000      -0.107      -0.039
# HML           -0.2871      0.057     -5.055      0.000      -0.406      -0.169
# RMW            0.6655      0.143      4.642      0.000       0.366       0.965
# ==============================================================================
# Omnibus:                        0.432   Durbin-Watson:                   2.362
# Prob(Omnibus):                  0.806   Jarque-Bera (JB):                0.134
# Skew:                          -0.178   Prob(JB):                        0.935
# Kurtosis:                       2.955   Cond. No.                         46.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.439
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     3.907
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):             0.0167
# Time:                        18:44:59   Log-Likelihood:                 67.843
# No. Observations:                  25   AIC:                            -125.7
# Df Residuals:                      20   BIC:                            -119.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0381      0.023      1.664      0.112      -0.010       0.086
# rm-rf          0.3413      0.175      1.953      0.065      -0.023       0.706
# SMB           -0.0805      0.048     -1.695      0.106      -0.180       0.019
# HML           -0.0567      0.253     -0.224      0.825      -0.584       0.471
# RMW            0.3144      0.150      2.102      0.048       0.002       0.627
# ==============================================================================
# Omnibus:                        3.925   Durbin-Watson:                   1.538
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.628
# Skew:                          -0.786   Prob(JB):                        0.269
# Kurtosis:                       3.229   Cond. No.                         84.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.691
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     11.16
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           6.37e-05
# Time:                        18:44:59   Log-Likelihood:                 76.579
# No. Observations:                  25   AIC:                            -143.2
# Df Residuals:                      20   BIC:                            -137.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0540      0.029      1.858      0.078      -0.007       0.115
# rm-rf          0.4167      0.231      1.806      0.086      -0.065       0.898
# SMB           -0.0935      0.049     -1.918      0.069      -0.195       0.008
# HML           -0.3347      0.126     -2.665      0.015      -0.597      -0.073
# RMW            0.8792      0.202      4.354      0.000       0.458       1.300
# ==============================================================================
# Omnibus:                        3.610   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.164   Jarque-Bera (JB):                2.205
# Skew:                          -0.223   Prob(JB):                        0.332
# Kurtosis:                       4.385   Cond. No.                         120.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     20.56
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           7.42e-07
# Time:                        18:44:59   Log-Likelihood:                 81.494
# No. Observations:                  25   AIC:                            -153.0
# Df Residuals:                      20   BIC:                            -146.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0294      0.023     -1.281      0.215      -0.077       0.018
# rm-rf         -0.2366      0.193     -1.229      0.233      -0.638       0.165
# SMB            0.0360      0.052      0.692      0.497      -0.072       0.144
# HML           -0.4640      0.100     -4.632      0.000      -0.673      -0.255
# RMW            0.4383      0.105      4.192      0.000       0.220       0.656
# ==============================================================================
# Omnibus:                        0.546   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.761   Jarque-Bera (JB):                0.264
# Skew:                           0.247   Prob(JB):                        0.876
# Kurtosis:                       2.908   Cond. No.                         110.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     44.54
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           1.10e-09
# Time:                        18:44:59   Log-Likelihood:                 92.039
# No. Observations:                  25   AIC:                            -174.1
# Df Residuals:                      20   BIC:                            -168.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0597      0.013     -4.697      0.000      -0.086      -0.033
# rm-rf         -0.4422      0.098     -4.517      0.000      -0.646      -0.238
# SMB            0.1112      0.028      4.026      0.001       0.054       0.169
# HML           -0.1154      0.049     -2.355      0.029      -0.218      -0.013
# RMW            0.3652      0.079      4.615      0.000       0.200       0.530
# ==============================================================================
# Omnibus:                        0.673   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.714   Jarque-Bera (JB):                0.250
# Skew:                          -0.245   Prob(JB):                        0.882
# Kurtosis:                       3.010   Cond. No.                         88.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     36.47
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           6.35e-09
# Time:                        18:44:59   Log-Likelihood:                 81.327
# No. Observations:                  25   AIC:                            -152.7
# Df Residuals:                      20   BIC:                            -146.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0089      0.016      0.543      0.593      -0.025       0.043
# rm-rf          0.0700      0.124      0.567      0.577      -0.188       0.328
# SMB           -0.0067      0.028     -0.237      0.815      -0.065       0.052
# HML           -0.3642      0.077     -4.754      0.000      -0.524      -0.204
# RMW            0.5248      0.069      7.587      0.000       0.380       0.669
# ==============================================================================
# Omnibus:                        0.092   Durbin-Watson:                   1.568
# Prob(Omnibus):                  0.955   Jarque-Bera (JB):                0.083
# Skew:                          -0.080   Prob(JB):                        0.959
# Kurtosis:                       2.768   Cond. No.                         65.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
