# %%
import pandas as pd
import statsmodels.api as sm

# %%
T = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
for t in T:
    df = pd.read_csv('../data/step3/{}.csv'.format(t), index_col=0)
    FX = df[['rm-rf', 'SMB', 'HML', 'RMW', 'CMA']]
    FY = df[['ri300-rf']]
    FX = sm.add_constant(FX)

    model = sm.OLS(FY, FX).fit()
    
    print(model.summary(), '\n\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     2.498
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):             0.0670
# Time:                        10:21:07   Log-Likelihood:                 29.624
# No. Observations:                  25   AIC:                            -47.25
# Df Residuals:                      19   BIC:                            -39.94
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2567      0.073     -3.529      0.002      -0.409      -0.104
# rm-rf          0.1482      0.287      0.516      0.612      -0.452       0.749
# SMB           -0.6150      0.822     -0.748      0.464      -2.336       1.106
# HML           -2.1289      0.874     -2.436      0.025      -3.958      -0.300
# RMW            0.4929      1.987      0.248      0.807      -3.665       4.651
# CMA            0.0704      1.938      0.036      0.971      -3.987       4.127
# ==============================================================================
# Omnibus:                        0.235   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.889   Jarque-Bera (JB):                0.292
# Skew:                           0.199   Prob(JB):                        0.864
# Kurtosis:                       2.650   Cond. No.                         161.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                 -0.063
# Method:                 Least Squares   F-statistic:                    0.7142
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):              0.620
# Time:                        10:21:07   Log-Likelihood:                 27.711
# No. Observations:                  25   AIC:                            -43.42
# Df Residuals:                      19   BIC:                            -36.11
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3523      0.126     -2.792      0.012      -0.616      -0.088
# rm-rf         -0.2504      0.486     -0.515      0.612      -1.267       0.766
# SMB            0.0448      0.953      0.047      0.963      -1.950       2.040
# HML           -1.1736      1.199     -0.979      0.340      -3.684       1.337
# RMW            0.6270      1.869      0.336      0.741      -3.284       4.538
# CMA           -0.8501      2.270     -0.375      0.712      -5.601       3.900
# ==============================================================================
# Omnibus:                        1.729   Durbin-Watson:                   1.604
# Prob(Omnibus):                  0.421   Jarque-Bera (JB):                0.772
# Skew:                           0.408   Prob(JB):                        0.680
# Kurtosis:                       3.277   Cond. No.                         159.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.9791
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):              0.456
# Time:                        10:21:07   Log-Likelihood:                 33.147
# No. Observations:                  25   AIC:                            -54.29
# Df Residuals:                      19   BIC:                            -46.98
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2637      0.087     -3.025      0.007      -0.446      -0.081
# rm-rf         -0.1204      0.361     -0.333      0.743      -0.877       0.636
# SMB           -0.1625      0.707     -0.230      0.821      -1.643       1.318
# HML           -0.1862      0.464     -0.402      0.693      -1.157       0.784
# RMW            0.8481      0.953      0.890      0.385      -1.147       2.843
# CMA           -1.9101      0.996     -1.918      0.070      -3.995       0.175
# ==============================================================================
# Omnibus:                        2.232   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                0.894
# Skew:                           0.198   Prob(JB):                        0.640
# Kurtosis:                       3.838   Cond. No.                         87.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     2.916
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):             0.0405
# Time:                        10:21:07   Log-Likelihood:                 32.678
# No. Observations:                  25   AIC:                            -53.36
# Df Residuals:                      19   BIC:                            -46.04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1637      0.094     -1.747      0.097      -0.360       0.032
# rm-rf          0.1594      0.409      0.390      0.701      -0.697       1.016
# SMB            0.0731      0.655      0.112      0.912      -1.298       1.445
# HML            0.7119      0.436      1.633      0.119      -0.200       1.624
# RMW           -1.2440      1.131     -1.100      0.285      -3.612       1.124
# CMA           -0.6974      1.111     -0.628      0.538      -3.022       1.627
# ==============================================================================
# Omnibus:                        0.201   Durbin-Watson:                   1.492
# Prob(Omnibus):                  0.904   Jarque-Bera (JB):                0.125
# Skew:                          -0.143   Prob(JB):                        0.939
# Kurtosis:                       2.803   Cond. No.                         107.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                 -0.047
# Method:                 Least Squares   F-statistic:                    0.7839
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):              0.574
# Time:                        10:21:07   Log-Likelihood:                 23.126
# No. Observations:                  25   AIC:                            -34.25
# Df Residuals:                      19   BIC:                            -26.94
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0790      0.054     -1.454      0.162      -0.193       0.035
# rm-rf          0.3829      0.282      1.358      0.190      -0.207       0.973
# SMB            0.1275      0.787      0.162      0.873      -1.520       1.775
# HML           -0.5302      0.737     -0.719      0.481      -2.073       1.012
# RMW            0.3220      1.066      0.302      0.766      -1.909       2.553
# CMA           -1.4616      1.055     -1.386      0.182      -3.670       0.746
# ==============================================================================
# Omnibus:                        5.097   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                3.155
# Skew:                          -0.692   Prob(JB):                        0.206
# Kurtosis:                       4.056   Cond. No.                         59.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                    0.9214
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):              0.489
# Time:                        10:21:07   Log-Likelihood:                 26.142
# No. Observations:                  25   AIC:                            -40.28
# Df Residuals:                      19   BIC:                            -32.97
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0790      0.044     -1.800      0.088      -0.171       0.013
# rm-rf          0.3390      0.295      1.150      0.264      -0.278       0.956
# SMB            0.9876      0.842      1.173      0.255      -0.775       2.750
# HML            1.5577      1.466      1.063      0.301      -1.510       4.625
# RMW            0.9070      0.836      1.085      0.292      -0.843       2.657
# CMA           -0.8550      1.139     -0.751      0.462      -3.239       1.529
# ==============================================================================
# Omnibus:                       11.514   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.527
# Skew:                          -1.061   Prob(JB):                      0.00314
# Kurtosis:                       5.562   Cond. No.                         87.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                 -0.101
# Method:                 Least Squares   F-statistic:                    0.5603
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):              0.729
# Time:                        10:21:07   Log-Likelihood:                 50.218
# No. Observations:                  25   AIC:                            -88.44
# Df Residuals:                      19   BIC:                            -81.12
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1403      0.031     -4.583      0.000      -0.204      -0.076
# rm-rf         -0.0957      0.239     -0.400      0.693      -0.596       0.404
# SMB            0.6034      0.388      1.556      0.136      -0.208       1.415
# HML            0.2501      0.440      0.568      0.577      -0.672       1.172
# RMW            1.2158      0.813      1.495      0.151      -0.487       2.918
# CMA           -0.3175      0.634     -0.501      0.622      -1.645       1.010
# ==============================================================================
# Omnibus:                        0.646   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.724   Jarque-Bera (JB):                0.177
# Skew:                          -0.204   Prob(JB):                        0.915
# Kurtosis:                       3.064   Cond. No.                         133.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                 -0.180
# Method:                 Least Squares   F-statistic:                    0.2680
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):              0.925
# Time:                        10:21:07   Log-Likelihood:                 34.659
# No. Observations:                  25   AIC:                            -57.32
# Df Residuals:                      19   BIC:                            -50.01
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0904      0.058     -1.554      0.137      -0.212       0.031
# rm-rf          0.1947      0.386      0.505      0.620      -0.613       1.002
# SMB            0.7674      0.994      0.772      0.450      -1.313       2.848
# HML            0.8696      1.010      0.861      0.400      -1.245       2.985
# RMW           -0.0034      1.015     -0.003      0.997      -2.128       2.121
# CMA            0.9728      1.487      0.654      0.521      -2.139       4.084
# ==============================================================================
# Omnibus:                       10.058   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                9.031
# Skew:                           0.993   Prob(JB):                       0.0109
# Kurtosis:                       5.173   Cond. No.                         131.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.439
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     2.978
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):             0.0377
# Time:                        10:21:07   Log-Likelihood:                 39.390
# No. Observations:                  25   AIC:                            -66.78
# Df Residuals:                      19   BIC:                            -59.47
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1022      0.039     -2.588      0.018      -0.185      -0.020
# rm-rf          0.2393      0.293      0.816      0.425      -0.375       0.853
# SMB           -0.8275      0.831     -0.996      0.332      -2.567       0.912
# HML           -1.5505      0.513     -3.021      0.007      -2.625      -0.476
# RMW            2.9423      0.958      3.071      0.006       0.937       4.948
# CMA           -5.5729      1.847     -3.018      0.007      -9.438      -1.708
# ==============================================================================
# Omnibus:                        1.866   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.393   Jarque-Bera (JB):                1.629
# Skew:                           0.574   Prob(JB):                        0.443
# Kurtosis:                       2.502   Cond. No.                         182.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ri300-rf   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                 -0.097
# Method:                 Least Squares   F-statistic:                    0.5738
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):              0.719
# Time:                        10:21:07   Log-Likelihood:                 45.733
# No. Observations:                  25   AIC:                            -79.47
# Df Residuals:                      19   BIC:                            -72.15
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0971      0.030     -3.223      0.004      -0.160      -0.034
# rm-rf          0.1335      0.232      0.577      0.571      -0.351       0.618
# SMB            0.4630      0.336      1.377      0.184      -0.241       1.167
# HML           -0.3788      0.450     -0.842      0.410      -1.320       0.563
# RMW           -0.1684      0.576     -0.292      0.773      -1.374       1.037
# CMA            0.0567      0.955      0.059      0.953      -1.942       2.055
# ==============================================================================
# Omnibus:                        3.997   Durbin-Watson:                   1.814
# Prob(Omnibus):                  0.136   Jarque-Bera (JB):                2.502
# Skew:                           0.334   Prob(JB):                        0.286
# Kurtosis:                       4.399   Cond. No.                         128.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
