# %%
import pandas as pd
import statsmodels.api as sm

# %%
T = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
for t in T:
    df = pd.read_csv('../data/step3/{}.csv'.format(t), index_col=0)
    FX = df[['rm-rf', 'SMB', 'HML', 'RMW']]
    FY = df[['CMA']]
    FX = sm.add_constant(FX)

    model = sm.OLS(FY, FX).fit()
    predictions = model.predict(FX)
    
    print(model.summary(), '\n\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     10.18
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           0.000116
# Time:                        14:07:01   Log-Likelihood:                 82.976
# No. Observations:                  25   AIC:                            -156.0
# Df Residuals:                      20   BIC:                            -149.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0153      0.008      2.003      0.059      -0.001       0.031
# rm-rf          0.0680      0.029      2.314      0.031       0.007       0.129
# SMB            0.0914      0.093      0.986      0.336      -0.102       0.285
# HML           -0.1619      0.094     -1.720      0.101      -0.358       0.034
# RMW            0.7971      0.144      5.534      0.000       0.497       1.098
# ==============================================================================
# Omnibus:                        1.135   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.567   Jarque-Bera (JB):                1.003
# Skew:                           0.295   Prob(JB):                        0.605
# Kurtosis:                       2.216   Cond. No.                         85.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     7.810
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           0.000582
# Time:                        14:07:01   Log-Likelihood:                 85.008
# No. Observations:                  25   AIC:                            -160.0
# Df Residuals:                      20   BIC:                            -153.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0334      0.010      3.367      0.003       0.013       0.054
# rm-rf          0.1169      0.040      2.915      0.009       0.033       0.201
# SMB            0.0096      0.094      0.102      0.920      -0.186       0.205
# HML           -0.1533      0.113     -1.356      0.190      -0.389       0.083
# RMW            0.6218      0.121      5.152      0.000       0.370       0.874
# ==============================================================================
# Omnibus:                        1.136   Durbin-Watson:                   1.398
# Prob(Omnibus):                  0.567   Jarque-Bera (JB):                0.222
# Skew:                          -0.066   Prob(JB):                        0.895
# Kurtosis:                       3.442   Cond. No.                         79.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     2.850
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):             0.0509
# Time:                        14:07:01   Log-Likelihood:                 69.853
# No. Observations:                  25   AIC:                            -129.7
# Df Residuals:                      20   BIC:                            -123.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0229      0.019      1.210      0.240      -0.017       0.062
# rm-rf          0.0805      0.079      1.018      0.321      -0.084       0.246
# SMB            0.0648      0.158      0.410      0.686      -0.265       0.395
# HML           -0.0958      0.102     -0.940      0.358      -0.308       0.117
# RMW            0.5527      0.175      3.164      0.005       0.188       0.917
# ==============================================================================
# Omnibus:                        6.405   Durbin-Watson:                   1.688
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                4.532
# Skew:                          -0.992   Prob(JB):                        0.104
# Kurtosis:                       3.646   Cond. No.                         58.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.489
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     4.784
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):            0.00716
# Time:                        14:07:01   Log-Likelihood:                 72.108
# No. Observations:                  25   AIC:                            -134.2
# Df Residuals:                      20   BIC:                            -128.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0536      0.015      3.684      0.001       0.023       0.084
# rm-rf          0.2191      0.066      3.308      0.004       0.081       0.357
# SMB            0.3235      0.110      2.932      0.008       0.093       0.554
# HML           -0.0855      0.086     -0.999      0.330      -0.264       0.093
# RMW            0.7010      0.165      4.243      0.000       0.356       1.046
# ==============================================================================
# Omnibus:                        0.059   Durbin-Watson:                   2.374
# Prob(Omnibus):                  0.971   Jarque-Bera (JB):                0.072
# Skew:                           0.048   Prob(JB):                        0.964
# Kurtosis:                       2.755   Cond. No.                         65.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     6.585
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):            0.00150
# Time:                        14:07:01   Log-Likelihood:                 61.268
# No. Observations:                  25   AIC:                            -112.5
# Df Residuals:                      20   BIC:                            -106.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0298      0.009      3.165      0.005       0.010       0.049
# rm-rf          0.1224      0.053      2.303      0.032       0.012       0.233
# SMB           -0.0638      0.166     -0.384      0.705      -0.411       0.283
# HML           -0.3860      0.130     -2.965      0.008      -0.658      -0.114
# RMW            0.3418      0.213      1.608      0.124      -0.102       0.785
# ==============================================================================
# Omnibus:                        6.581   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                4.659
# Skew:                           0.762   Prob(JB):                       0.0973
# Kurtosis:                       4.466   Cond. No.                         53.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.360
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     2.812
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):             0.0530
# Time:                        14:07:01   Log-Likelihood:                 66.204
# No. Observations:                  25   AIC:                            -122.4
# Df Residuals:                      20   BIC:                            -116.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.009     -0.226      0.824      -0.020       0.016
# rm-rf         -0.0562      0.056     -0.995      0.331      -0.174       0.062
# SMB           -0.0408      0.165     -0.247      0.807      -0.385       0.304
# HML           -0.4720      0.268     -1.764      0.093      -1.030       0.086
# RMW            0.1963      0.158      1.241      0.229      -0.134       0.526
# ==============================================================================
# Omnibus:                        5.735   Durbin-Watson:                   1.740
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                4.483
# Skew:                           0.487   Prob(JB):                        0.106
# Kurtosis:                       4.831   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.600
# Method:                 Least Squares   F-statistic:                     9.991
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           0.000131
# Time:                        14:07:01   Log-Likelihood:                 75.644
# No. Observations:                  25   AIC:                            -141.3
# Df Residuals:                      20   BIC:                            -135.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0042      0.011     -0.394      0.697      -0.027       0.018
# rm-rf         -0.0298      0.084     -0.355      0.726      -0.205       0.145
# SMB            0.1832      0.130      1.405      0.175      -0.089       0.455
# HML           -0.3627      0.132     -2.741      0.013      -0.639      -0.087
# RMW            0.8250      0.219      3.759      0.001       0.367       1.283
# ==============================================================================
# Omnibus:                        4.648   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.098   Jarque-Bera (JB):                3.094
# Skew:                           0.436   Prob(JB):                        0.213
# Kurtosis:                       4.487   Cond. No.                         99.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     20.32
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           8.13e-07
# Time:                        14:07:01   Log-Likelihood:                 81.377
# No. Observations:                  25   AIC:                            -152.8
# Df Residuals:                      20   BIC:                            -146.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0109      0.008      1.299      0.209      -0.007       0.028
# rm-rf          0.0937      0.054      1.732      0.099      -0.019       0.207
# SMB           -0.0798      0.148     -0.537      0.597      -0.389       0.230
# HML           -0.4629      0.111     -4.158      0.000      -0.695      -0.231
# RMW            0.4445      0.116      3.835      0.001       0.203       0.686
# ==============================================================================
# Omnibus:                        0.546   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.761   Jarque-Bera (JB):                0.259
# Skew:                          -0.245   Prob(JB):                        0.879
# Kurtosis:                       2.913   Cond. No.                         97.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     42.57
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           1.64e-09
# Time:                        14:07:01   Log-Likelihood:                 91.531
# No. Observations:                  25   AIC:                            -173.1
# Df Residuals:                      20   BIC:                            -167.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.478e-06      0.005      0.001      0.999      -0.010       0.010
# rm-rf         -0.0077      0.035     -0.217      0.830      -0.082       0.066
# SMB           -0.2933      0.076     -3.843      0.001      -0.453      -0.134
# HML           -0.1577      0.051     -3.084      0.006      -0.264      -0.051
# RMW            0.3780      0.079      4.756      0.000       0.212       0.544
# ==============================================================================
# Omnibus:                        0.404   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.817   Jarque-Bera (JB):                0.451
# Skew:                           0.262   Prob(JB):                        0.798
# Kurtosis:                       2.602   Cond. No.                         77.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     36.66
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           6.08e-09
# Time:                        14:07:01   Log-Likelihood:                 81.383
# No. Observations:                  25   AIC:                            -152.8
# Df Residuals:                      20   BIC:                            -146.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0056      0.007     -0.801      0.433      -0.020       0.009
# rm-rf         -0.0444      0.053     -0.834      0.414      -0.156       0.067
# SMB           -0.0300      0.078     -0.383      0.706      -0.194       0.134
# HML           -0.3405      0.073     -4.676      0.000      -0.492      -0.189
# RMW            0.5204      0.068      7.631      0.000       0.378       0.663
# ==============================================================================
# Omnibus:                        0.053   Durbin-Watson:                   1.400
# Prob(Omnibus):                  0.974   Jarque-Bera (JB):                0.208
# Skew:                           0.092   Prob(JB):                        0.901
# Kurtosis:                       2.593   Cond. No.                         45.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
